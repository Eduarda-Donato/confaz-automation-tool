# %%
import pandas as pd
import numpy as np
#import matplotlib

# %%
df = pd.read_excel("C:\\Users\\maria.donato\\Documents\\Portfolio\\sistema_confaz\\BD\\BD.xlsx", sheet_name="Plan1")
df
# Out:
#                       ITEM  ESPÉCIE  \
# 0                        9     10.0
# 1                        1     10.0
# 2                      NaN     10.0
# 3                       39     10.0
# 4                       11      8.0
# ...                    ...      ...
# 2001                    69     10.0
# 2002                    98      8.0
# 2003                     3      8.0
# 2004                    17      8.0
# 2005  BENEFÍCIOS - 04/2025      NaN
#
#                                                  NÚMERO                 DATA  \
# 0                        e201902417-9  2010.01.00.00042  2019-09-02 00:00:00
# 1                        e201902606-6  2017.01.00.00138  2019-09-02 00:00:00
# 2                        e201902708-9  2017.01.00.00151  2019-09-13 00:00:00
# 3                         e201903511-1 2017.01.00.00134  2019-09-17 00:00:00
# 4                        e201902493-4  2006.01.00.00160  2019-09-10 00:00:00
# ...
